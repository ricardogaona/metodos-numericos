# %%
import math
# RK-2 method python program

# RK-2 method
def rk2(expr_xy, x0,y0,xn,n, decimales=6):
    
    # Definimos la función en base a la expresión ingresada
    def f(x, y):
        f = eval(expr_xy)
        return f
    
    # Calculating step size
    h = round((xn-x0)/n, decimales)
    
    X = [x0 + i*h for i in range(n+1)]
    
    Y = [y0, *[0]*n]
    print('\n--------SOLUCIÓN--------\n')
    for i in range(n):
        print("Iteración #%d\n" % (i+1))
        k1 = round(h * (f(X[i], Y[i])), decimales)
        print("k1 = %.{0}f * f(%.{0}f, %.{0}f) = %.{0}f".format(decimales) % (h, X[i], Y[i], k1))
        k2 = round(h * (f((X[i]+h), (Y[i]+k1))), decimales)
        print("k2 = %.{0}f * f(%.{0}f, %.{0}f) = %.{0}f".format(decimales) % (h, X[i]+h, Y[i]+k1, k2))
       
        Y[i+1] = round(Y[i] + (k1+k2)/2, decimales)
        print("y%d = %.{0}f + (%.{0}f + %.{0}f) / 2 = %.{0}f\n".format(decimales) % (i+1, Y[i], k1, k2, Y[i+1]))
#         print('%d\t%.6f\t%.6f'% (i+1,X[i+1],Y[i+1]) )
#         print('--------------------------------------------------')
    
    print('--------------------------------------------------')    
    print('i\t\txi\t\tyi')
    print('--------------------------------------------------')
    
    print("%d\t\t%.{0}f\t%.{0}f".format(decimales) % (0, X[0],Y[0]) )
    print('--------------------------------------------------')
    for i in range(n):
        print("%d\t\t%.{0}f\t%.{0}f".format(decimales) % (i+1,X[i+1],Y[i+1]) )
        print('--------------------------------------------------')
    print("\ny(%.{0}f) = %.{0}f".format(decimales) % (X[n],Y[n]))

# Inputs
expr_xy = input("Ingrese la expresión que define a la función: ")
print('Condiciones iniciales: ')
x0 = float(input('x0 = '))
y0 = float(input('y0 = '))

print('El punto a calcular: ')
xn = float(input('xn = '))

print('Número de pasos:')
step = int(input('iteraciones = '))
dec = int(input('Cantidad de decimales: '))

# RK2 method call
rk2(expr_xy,x0,y0,xn,step, decimales=dec)
# Out:
# Ingrese la expresión que define a la función: -2*x**3 + 12*x**2 - 20*x + 8.5
# Condiciones iniciales:
# x0 = 0
# y0 = 1
# El punto a calcular:
# xn = 4
# Número de pasos:
# iteraciones = 8
# Cantidad de decimales: 6
#
# --------SOLUCIÓN--------
#
# Iteración #1
#
# k1 = 0.500000 * f(0.000000, 1.000000) = 4.250000
# k2 = 0.500000 * f(0.500000, 5.250000) = 0.625000
# y1 = 1.000000 + (4.250000 + 0.625000) / 2 = 3.437500
#
# Iteración #2
#
# k1 = 0.500000 * f(0.500000, 3.437500) = 0.625000
# k2 = 0.500000 * f(1.000000, 4.062500) = -0.750000
# y2 = 3.437500 + (0.625000 + -0.750000) / 2 = 3.375000
#
# Iteración #3
#
# k1 = 0.500000 * f(1.000000, 3.375000) = -0.750000
# k2 = 0.500000 * f(1.500000, 2.625000) = -0.625000
# y3 = 3.375000 + (-0.750000 + -0.625000) / 2 = 2.687500
#
# Iteración #4
#
# k1 = 0.500000 * f(1.500000, 2.687500) = -0.625000
# k2 = 0.500000 * f(2.000000, 2.062500) = 0.250000
# y4 = 2.687500 + (-0.625000 + 0.250000) / 2 = 2.500000
#
# Iteración #5
#
# k1 = 0.500000 * f(2.000000, 2.500000) = 0.250000
# k2 = 0.500000 * f(2.500000, 2.750000) = 1.125000
# y5 = 2.500000 + (0.250000 + 1.125000) / 2 = 3.187500
#
# Iteración #6
#
# k1 = 0.500000 * f(2.500000, 3.187500) = 1.125000
# k2 = 0.500000 * f(3.000000, 4.312500) = 1.250000
# y6 = 3.187500 + (1.125000 + 1.250000) / 2 = 4.375000
#
# Iteración #7
#
# k1 = 0.500000 * f(3.000000, 4.375000) = 1.250000
# k2 = 0.500000 * f(3.500000, 5.625000) = -0.125000
# y7 = 4.375000 + (1.250000 + -0.125000) / 2 = 4.937500
#
# Iteración #8
#
# k1 = 0.500000 * f(3.500000, 4.937500) = -0.125000
# k2 = 0.500000 * f(4.000000, 4.812500) = -3.750000
# y8 = 4.937500 + (-0.125000 + -3.750000) / 2 = 3.000000
#
# --------------------------------------------------
# i		xi		yi
# --------------------------------------------------
# 0		0.000000	1.000000
# --------------------------------------------------
# 1		0.500000	3.437500
# --------------------------------------------------
# 2		1.000000	3.375000
# --------------------------------------------------
# 3		1.500000	2.687500
# --------------------------------------------------
# 4		2.000000	2.500000
# --------------------------------------------------
# 5		2.500000	3.187500
# --------------------------------------------------
# 6		3.000000	4.375000
# --------------------------------------------------
# 7		3.500000	4.937500
# --------------------------------------------------
# 8		4.000000	3.000000
# --------------------------------------------------
#
# y(4.000000) = 3.000000
