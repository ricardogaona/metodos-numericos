# %%
from pprint import pprint
from numpy import array, zeros, diag, diagflat, dot, concatenate

def print_ecuaciones(A, b, decimales=6):
    AUG = concatenate((A, b),axis=1)

    for i in range(len(AUG)):
        print("x%d^(k) = " % (i+1), end='')
        for j in range(len(AUG[0])):
            if i == j or AUG[i][j] == 0:
                print("0", end='') if j == 0 else print(" + 0", end='')
            else:
                if j == 0:
                    print("%.{}fx%d".format(decimales) % (-AUG[i][j]/AUG[i][i], j), end='')
                else:
                    numerador = AUG[i][j] if j == len(AUG[0])-1 else -AUG[i][j]
                    
                    print(" + ", end='') if numerador/AUG[i][i] > 0 else print(" - ", end='')

                    print("%.{}fx%d".format(decimales) % (abs(numerador/AUG[i][i]), j), end='')
                print("^(k)", end='') if j < i else print("^(k-1)", end='')
        print("")

def gauss_seidel(A, b, N, decimales=6, x=None):
    
    if x is None:
        x = zeros(len(A[0]))
    
    print("\n\nSOLUCIÓN\n")
    print("Ecuaciones para la k-ésima iteración:\n")
    print_ecuaciones(A, b, decimales)
    
    print("\nIteraciones\n")
    b = b.flatten()
        
    for k in range(N):
        for i in range(len(x)):
            suma = 0
            for j in range(len(x)):
                if i != j:
                    suma += A[i][j] * x[j]
            x[i] = (-suma + b[i]) / A[i][i]
        print("iteracion %d ->\t" % (k+1), end='')
        for j in range(len(x)):
            print("%.{}f\t\t".format(decimales) % x[j], end='')
        print()
        

n = int(input("Cantidad de incógnitas: "))

A = zeros((n,n))
print('\nCoeficientes de la matriz A:')
for i in range(n):
    for j in range(n):
        A[i][j] = float(input( 'A['+str(i)+']['+ str(j)+']='))
            
b = zeros((n,1))
print('\nCoeficientes de la matriz b:')
for i in range(n):
    b[i][0] = float(input( 'b['+str(i)+']['+ str(j)+']='))
            

dec = int(input("\nCantidad de decimales: "))
iteraciones = int(input("\nCantidad de iteraciones: "))

# A = array([[10, -1, 2, 0],
#            [-1, 11, -1, 3],
#            [2, -1, 10, -1],
#            [0, 3, -1, 8]])

# b = array([[6], [25], [-11], [15]])

gauss_seidel(A, b, iteraciones, decimales=dec)
# b = array([[6], [25], [-11], [15]])
# print_ecuaciones(A, b, 6)
# Out:
# Cantidad de incógnitas: 4
#
# Coeficientes de la matriz A:
# A[0][0]=10
# A[0][1]=-1
# A[0][2]=2
# A[0][3]=0
# A[1][0]=-1
# A[1][1]=11
# A[1][2]=-1
# A[1][3]=3
# A[2][0]=2
# A[2][1]=-1
# A[2][2]=10
# A[2][3]=-1
# A[3][0]=0
# A[3][1]=3
# A[3][2]=-1
# A[3][3]=8
#
# Coeficientes de la matriz b:
# b[0][3]=6
# b[1][3]=25
# b[2][3]=-11
# b[3][3]=15
#
# Cantidad de decimales: 4
#
# Cantidad de iteraciones: 5
#
#
# SOLUCIÓN
#
# Ecuaciones para la k-ésima iteración:
#
# x1^(k) = 0 + 0.1000x1^(k-1) - 0.2000x2^(k-1) + 0 + 0.6000x4^(k-1)
# x2^(k) = 0.0909x0^(k) + 0 + 0.0909x2^(k-1) - 0.2727x3^(k-1) + 2.2727x4^(k-1)
# x3^(k) = -0.2000x0^(k) + 0.1000x1^(k) + 0 + 0.1000x3^(k-1) - 1.1000x4^(k-1)
# x4^(k) = 0 - 0.3750x1^(k) + 0.1250x2^(k) + 0 + 1.8750x4^(k-1)
#
# Iteraciones
#
# iteracion 1 ->	0.6000		2.3273		-0.9873		0.8789
# iteracion 2 ->	1.0302		2.0369		-1.0145		0.9843
# iteracion 3 ->	1.0066		2.0036		-1.0025		0.9984
# iteracion 4 ->	1.0009		2.0003		-1.0003		0.9998
# iteracion 5 ->	1.0001		2.0000		-1.0000		1.0000
